# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"D:\amazon_ecommerce_1M.csv")

# %%
df.head(10)
# Out:
#    user_id product_id     category subcategory    brand     price  discount  \
# 0  U356787     P39256  Electronics      Mobile      H&M  33090.51     10.46
# 1  U198246     P38657       Sports     Outdoor  Samsung   9368.97      5.32
# 2  U539898     P38893       Sports     Fitness      H&M  14756.85     26.00
# 3  U325772     P54118       Beauty      Makeup     Sony    668.83     24.81
# 4  U865179     P70217         Home       Decor     Sony  10881.29     48.63
# 5  U705397     P35203         Home       Decor       HP   6155.63     17.64
# 6  U498591     P46434         Home   Furniture   Adidas   1104.92     37.81
# 7  U738720     P93227     Clothing        Kids     Sony   1899.42     63.23
# 8  U330283     P99733       Beauty      Makeup     Sony   3611.18     24.77
# 9  U694731     P51245       Beauty      Makeup    Apple   3826.65      8.46
#
#    final_price  rating  review_count  stock seller_id  seller_rating  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   user_id             1000000 non-null  object
#  1   product_id          1000000 non-null  object
#  2   category            1000000 non-null  object
#  3   subcategory         1000000 non-null  object
#  4   brand               1000000 non-null  object
#  5   price               1000000 non-null  float64
#  6   discount            1000000 non-null  float64
#  7   final_price         1000000 non-null  float64
#  8   rating              1000000 non-null  float64
#  9   review_count        1000000 non-null  int64
#  10  stock               1000000 non-null  int64
#  11  seller_id           1000000 non-null  object
#  12  seller_rating       1000000 non-null  float64
#  13  purchase_date       1000000 non-null  object
# ...

# %%
df.describe(include='all')
# Out:
#         user_id product_id category subcategory    brand           price  \
# count   1000000    1000000  1000000     1000000  1000000  1000000.000000
# unique   603815      89999        5          16       12             NaN
# top     U678771     P96731     Home       Decor       LG             NaN
# freq          9         28   200922       67260    83882             NaN
# mean        NaN        NaN      NaN         NaN      NaN    13224.119093
# std         NaN        NaN      NaN         NaN      NaN    18079.626921
# min         NaN        NaN      NaN         NaN      NaN      200.030000
# 25%         NaN        NaN      NaN         NaN      NaN     2700.147500
# 50%         NaN        NaN      NaN         NaN      NaN     4971.830000
# 75%         NaN        NaN      NaN         NaN      NaN    14134.482500
# max         NaN        NaN      NaN         NaN      NaN    79999.700000
#
#               discount     final_price          rating    review_count  \
# ...

# %%
df.isnull().sum()
# Out:
# user_id               0
# product_id            0
# category              0
# subcategory           0
# brand                 0
# price                 0
# discount              0
# final_price           0
# rating                0
# review_count          0
# stock                 0
# seller_id             0
# seller_rating         0
# purchase_date         0
# shipping_time_days    0
# location              0
# device                0
# payment_method        0
# is_returned           0
# delivery_status       0
# dtype: int64

# %%
df['purchase_date']=pd.to_datetime(df['purchase_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   user_id             1000000 non-null  object
#  1   product_id          1000000 non-null  object
#  2   category            1000000 non-null  object
#  3   subcategory         1000000 non-null  object
#  4   brand               1000000 non-null  object
#  5   price               1000000 non-null  float64
#  6   discount            1000000 non-null  float64
#  7   final_price         1000000 non-null  float64
#  8   rating              1000000 non-null  float64
#  9   review_count        1000000 non-null  int64
#  10  stock               1000000 non-null  int64
#  11  seller_id           1000000 non-null  object
#  12  seller_rating       1000000 non-null  float64
#  13  purchase_date       1000000 non-null  datetime64[ns]
# ...

# %%
df.head(5)
df['Saving']=df['price']-df['final_price']

# %%
labels=['Budget','Mid','Primium','Luxury']
df['price_bucket']=pd.qcut(df['price'],q=4,labels=labels)

# %%
col=['price','discount','final_price','saving','rating']
# Out:
#    user_id product_id     category subcategory    brand     price  discount  \
# 0  U356787     P39256  Electronics      Mobile      H&M  33090.51     10.46
# 1  U198246     P38657       Sports     Outdoor  Samsung   9368.97      5.32
# 2  U539898     P38893       Sports     Fitness      H&M  14756.85     26.00
# 3  U325772     P54118       Beauty      Makeup     Sony    668.83     24.81
# 4  U865179     P70217         Home       Decor     Sony  10881.29     48.63
# 5  U705397     P35203         Home       Decor       HP   6155.63     17.64
# 6  U498591     P46434         Home   Furniture   Adidas   1104.92     37.81
# 7  U738720     P93227     Clothing        Kids     Sony   1899.42     63.23
# 8  U330283     P99733       Beauty      Makeup     Sony   3611.18     24.77
#
#    final_price  rating  review_count  ...  purchase_date shipping_time_days  \
# 0     29629.31     4.9            43  ...     2025-03-04                  6
# ...

# %%
#total no.of devices for each type

df1= (df
      .groupby('device',as_index=False)
      ['product_id']
      .count()
      .rename(columns={'product_id':'no_of_products'})
      .set_index('device')
      .plot.bar()
     )

# %%
df['price'].describe(include='all')
# Out:
# count    1000000.000000
# mean       13224.119093
# std        18079.626921
# min          200.030000
# 25%         2700.147500
# 50%         4971.830000
# 75%        14134.482500
# max        79999.700000
# Name: price, dtype: float64

# %%
df.head(10)
# Out:
#    user_id product_id     category subcategory    brand     price  discount  \
# 0  U356787     P39256  Electronics      Mobile      H&M  33090.51     10.46
# 1  U198246     P38657       Sports     Outdoor  Samsung   9368.97      5.32
# 2  U539898     P38893       Sports     Fitness      H&M  14756.85     26.00
# 3  U325772     P54118       Beauty      Makeup     Sony    668.83     24.81
# 4  U865179     P70217         Home       Decor     Sony  10881.29     48.63
# 5  U705397     P35203         Home       Decor       HP   6155.63     17.64
# 6  U498591     P46434         Home   Furniture   Adidas   1104.92     37.81
# 7  U738720     P93227     Clothing        Kids     Sony   1899.42     63.23
# 8  U330283     P99733       Beauty      Makeup     Sony   3611.18     24.77
# 9  U694731     P51245       Beauty      Makeup    Apple   3826.65      8.46
#
#    final_price  rating  review_count  ...  purchase_date shipping_time_days  \
# ...

# %%
df.groupby('psyment_method',as_index=False)

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
#
# ...

# %%
from sqlalchemy import create_engine
username="postgres"
password="tilak123"
host="localhost"
port=5432
database="amazone_e-commerce"
engine=create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")
table_name='customers'
df.to_sql(table_name,engine,if_exists='replace',index=False)
print(f"data sucessfully loaded into table'{table_name}'in database '{database}'.")
# Out:
# data sucessfully loaded into table'customers'in database 'amazone_e-commerce'.
